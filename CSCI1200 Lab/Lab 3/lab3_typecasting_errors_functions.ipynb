# %%
# You'll fill this part in when it's time to work on computers
#
# Write your names here:
# Ashish Srivastava
# 
# Turn this file in on Canvas before you leave lab, even if you haven't finished!
# We want to see where you got to so that we can know where to pick up from.

# %% [markdown]
# # Lab 3 - CSCI 1200
# ## Fall 2020
# ***
# Welcome to the lab, today we will be primarily learning about the following concepts:
# 1. Type Casting
# 2. Errors
# 3. Using functions
#
# We will walk through half of this notebook at the beginning of the recitation, and the rest you will be doing in Computer Time!

# %% [markdown]
# # 1. Type Casting
# ***
#
# Sometimes we need to change a value from one type to another. We will try some casting functions below, lets see what all kinds commands are valid/ invalid and what errors are produced alongside.
# See [section 3.4 of the notes](https://muzny.github.io/csci1200-notes/03/4/casting.html) for more information on casting (interchangeably called type conversion in the textbook).

# %%
# lets talk about the type() function.
# remember that these functions return values so if we want to do
# anything with them, we need to save them in variables.

t1 = type(1.0)
t2 = type("Sacred Games")
t3 = type (10000)
t4 = type(True)

# %%
whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# os         module    <module 'os' from '/Users<...>da3/lib/python3.7/os.py'>
# sys        module    <module 'sys' (built-in)>
# t1         type      <class 'float'>
# t2         type      <class 'str'>
# t3         type      <class 'int'>
# t4         type      <class 'bool'>

# %%
# what happens when we cast something into int?
# we'll use print statements to print out the value 


# i1 = int("10")
# print(i1)
# i2 = int("10.0")
# print(i2)
# i3 = int(10.34)
# print(i3)
# i4 = int("True")
# print(i4)
# i5 = int(True)
# print(i5)
# Out:
# 1

# %%
# what happens when we cast something to float? 

# f1 = float("10.0")
# f2 = float("10")
# f3 = float(10)
# f4 = float("csci1200")
# f5 = float(False)

# %%
# let's try casting different values to strings?

# s1 = str(10.0)
# s2 = str(1000)
# s3 = str(True)
# s4 = str("csci1200")

# %%
# lets try casting with input, debug the following code line by line

fav_num = input("Please write your favorite number here: ")
magic = 5 + int(fav_num)
print("Your favorite number plus five is: " + str(magic))
print("Your favorite number plus five is: {}".format(magic)) # using format
print(f"Your favorite number plus five is: {magic}") # using fstrings
# Out:
# Your favorite number plus five is: 9
# Your favorite number plus five is: 9
# Your favorite number plus five is: 9

# %% [markdown]
# # 2. Errors
# ***
#
# We noted a number of errors above. Let's think once about the kind of errors that occured and why they occured?

# %%
# We can get important information from error messages:
# 1) what is the type of error?
# NameError
# 2) what line caused the error?
# Line  10
# 3) what exactly caused the error?
# The variable abc_var is not defined


print(abc_var)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a72e4b149819> in <module>
#       8
#       9
# ---> 10 print(abc_var)
#
# NameError: name 'abc_var' is not defined

# %%
# We can get important information from error messages:
# 1) what is the type of error?
# 2) what line caused the error?
# 3) what exactly caused the error?


# year = 1776
# print("US got independence in: " + year)

# %%
# We can get important information from error messages:
# 1) what is the type of error?
# 2) what line caused the error?
# 3) what exactly caused the error?

# a = 25 % 5
# print(a)
# b = 5 + a
# print(b)
# c = b / a
# print(c)
# Out:
# 0
# 5
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-23-24bdbecd8396> in <module>
#       8 b = 5 + a
#       9 print(b)
# ---> 10 c = b / a
#      11 print(c)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # 3. Using Functions
# ***
#
# Let's talk about a new concept now. Functions are the detailed representation of tasks that you would like your program to do. Let's go through the following examples to explore a few more functions.
#
# See [the official Python documentation](https://docs.python.org/3/library/functions.html) for information about ALL built-in functions.

# %%
# Using built-in functions

x = "this is a string"
len_x = len(x)
print(len_x)

x = -100
y = -10

print(min(x, y))
print(max(x, y))

word_type = type("csci1200")

x = 2.3332323524234234
rounded1 = round(x,10)
rounded2 = round(x)
# Out:
# 16
# -100
# -10

# %% [markdown]
# # Paper Time!
# ***
# Go ahead and solve the exercises on paper!

# %% [markdown]
# # Computer Time!
# ***
# Go ahead and solve the following exercises centered around using functions.

# %% [markdown]
# 0. Trace the value of the variable `lets_math` in the following code snippet. Write its value and type in comments next to each line.

# %%
lets_math = 72  # example: 72, int
lets_math = lets_math * 3.14159 # 226.19448, float
lets_math = 4 # 4, int
lets_math = lets_math + lets_math * 8 # 36, int
lets_math = str(lets_math) # 36, str
lets_math = len(lets_math) #2, int

# %% [markdown]
# 1. Ask the user to input a number. Convert this number to a `float`, then convert the float version to an `int`, then convert the int version to a `bool`. Print out the user's input after each conversion step.

# %%
your_num = input("Please input a number")
print("Your number is: " + str(your_num))
your_num = float(your_num)
print("Your number as a float is: " + str(your_num))
your_num = int(your_num)
print("Your number as an int is: " + str(your_num))
your_num = bool(your_num)
print("Your number as a bool is: " + str(your_num))
# Out:
# Your number is: -5
# Your number as a float is: -5.0
# Your number as an int is: -5
# Your number as a bool is: True

# %% [markdown]
# 2. Read [the python documentation on `pow()`](https://docs.python.org/3/library/functions.html#pow).
#
# Take 2 numbers as input from the user, then use the `pow()` function to print the result of the first number raised to the second number. Then, use the `**` operator to do the same calculation. Feel free to experiment to figure out exactly how to do this!
#
# Here is some example output (__3__ and __2__ are entered by the user).
# ```
# Number 1: 3
# Raised to: 2
# with pow(): 9
# with **: 9
# ```

# %%
num_1 = int(input("Number 1: "))
power = int(input("Raised to"))
print("with pow(): " + str(pow(num_1,power)))
print("with **: " + str(num_1**power))
# Out:
# with pow(): 9
# with **: 9

# %% [markdown]
# 3. Take 5 numbers as input from the user (use 5 calls to the `input()` function) and print the minimum of those 5 numbers. Use the [`min()`](https://docs.python.org/3/library/functions.html#min) function.

# %%
x1 = input("Input a number")
x2 = input("Input a second number")
x3 = input("Input a third number")
x4 = input("Input a fourth number")
x5 = input("Input a fifth number")
print(min(x1,x2,x3,x4,x5))


# # Alternative using lists:
# num_list = []
# for i in range(5):
#     num_list.append(float(input("Input a number")))
# print(min(num_list))
# Out:
# 2.0

# %% [markdown]
# 4. Get input from the user, then use the [`len()`](https://docs.python.org/3/library/functions.html#len) function to print out how long the user's input was.

# %%
user_input = input("Give an input")
print("The length of the user input was: " + str(len(user_input)))
# Out:
# The length of the input was: 8

# %% [markdown]
# When you're done, do the following:
# 1. Turn this notebook in on Canvas. If you worked with a partner: add a comment to your submission on canvas with the name of your partner.
# 2. Work on homework 2! (do this individually if you get this far)
