# %%
# You'll fill this part in when it's time to work on computers
#
# Ashish Srivastava
#

# %% [markdown]
# # Lab 4 - CSCI 1200
#
# ***
# Welcome to the lab, today you will:
# 1. design the solution to a few problems in pseudocode
# 2. write functions that use parameters
# 3. write functions that return values
#
# We will walk through half of this notebook at the beginning of the recitation, and the rest you will be doing in Computer Time!

# %% [markdown]
# # 1. Pseudocode
# ***
#
# Before starting to code a solution to a problem, it is always better to think about it and design your solution on a paper. Pseudocode helps us refine our solution/ideas in a format that can be easily translated into code. Let's look at how we can go about thinking pseudocode before writing the actual code:

# %%
# Write pseudocode for a program that figures out how many materials
# the user is missing to build a treehouse. 
# A treehouse takes the following: 
# 1 sturdy tree
# 20 large boards
# 100 nails
# 50 feet of rope
# 1 name plate

# Step 1: input the items 
# Step 2: Initialize variables: sturdy_tree, boards, nails, rope_len, plate
# Step 3: Check for each item the user has missing
# Step 4: Sttore the values of the missing items
# Step 5: output the missing items

# %%
# Write pseudocode for a program that converts any number of seconds
# to a number of hours.

# Step 1: input number of seconds
# Step 2: convert to hours by dividing by 3600
# Step 3: output number of hours

# %% [markdown]
# # 2. Functions & Parameters
# ***
#
# Sometimes, in order for a function to do its task, we need to provide it with some input. This input is a parameter or parameters. Let's see some examples below:

# %%
# # What are parameters

def my_function(s):
    print("Hello from a function")
    print("I have been given the parameter: "+s)

my_function("internet")
# Out:
# Hello from a function
# I have been given the parameter: internet

# %%
# Writing function to convert seconds to hours,
# but this time using parameters instead of asking user's input

# define the function with name "convert_seconds_to_hours" that 
# accepts "seconds" as a parameter
#     # first get minutes from seconds
#     # then get hours from minutes
#     # print the number of hours

# call the convert function here

def convert_seconds_to_hours(seconds):
    mins = seconds/60
    hours = mins/60
    print(str(hours) + " hours")

convert_seconds_to_hours(3600)
# Out:
# 1.0 hours

# %% [markdown]
# # 3. Functions & Returns
# ***
#
# After finishing its task, a function with a return value (sometimes these are called prolific functions) will give back some output value. Let's see how that works!

# %%
def my_function(param):
    print("Hello from a function. You have passed the parameter: "+param)
    print("I am returning a word now.")
    ret = "Apple " + param
    return ret

receive = my_function("csci1200")
print("I am outside the function and I have received: "+receive)
# Out:
# Hello from a function. You have passed the parameter: csci1200
# I am returning a word now.
# I am outside the function and I have received: Apple csci1200

# %%
# Let's write another version of our convert_seconds_to_hours function
# define the function with name "convert_seconds_to_hours" 
# that takes in "seconds" as a parameter
#     # first get minutes from seconds
#     # then get hours from minutes
#     # return number of hours

def convert_seconds_to_hours(seconds):
    mins = seconds/60
    hours = mins/60
    return hours

# define "main" function
#     # welcome the user to the program
#     # ask for the number of seconds to convert to hours
#     # call the "convert_seconds_to_hours" function to calculate hours from seconds
#     # print the number of hours here

def main():
    print("Welcome to the program")
    seconds = float(input("Give a number of seconds to convert to hours:"))
    hours = convert_seconds_to_hours(seconds)
    return hours

# call the "main" function
main()
# Out:
# Welcome to the program
# 1.0

# %% [markdown]
# # PAPER TIME!
# ***
# Solve the exercises in the individual worksheet.

# %% [markdown]
# # COMPUTER TIME!
# ***
# Solve the following programming exercises.

# %% [markdown]
# 1) Write a function, ```square_area_print```, that takes one parameter, ```size```, calculates the area of a square, and __prints__ it in the function. This function has no return value. For example, a call of ```square_area_print(4)``` would print the output: ```"This square is 16 units squared."``` The area of a square is calculated according to the equation ```area = size * size```.

# %%
def square_area_print(size):
    area = size * size
    print("This square is " + str(area) + " units squared.")

# %% [markdown]
# 2) Change your function from question #1 so that it __returns__ the value instead of printing it. Write this updated function as `square_area`.

# %%
def square_area(size):
    area = size * size
    return area

# %% [markdown]
# 3)	Write a function, ```triangle_area```, that takes one parameter, ```size```, calculates the area of a triangle with height and base equal to size, and __returns__ it. For example, a call of ```triangle_area(4)``` would return the value `8`. After you call your function, print out a message about the area of the triangle with the value returned by the function. For example: ```"This triangle is 8 units squared."``` The area of a triangle is calculated according to the equation ```area = (½)* base * height```.

# %%
def triangle_area(size):
    base = size
    height = size
    area = 0.5 * base * height
    return area

print("This triangle is " + str(triangle_area(4)) + " units squared")
# Out:
# This triangle is 8.0 units squared

# %% [markdown]
# 4)	Write a function, ```rectangle_area```, that takes two parameters, ```width``` and ```height```, calculates the area of a rectangle, and __returns__ it. For example, a call of ```rectangle_area(4, 10)``` would return the value `40`. You should then print out a message with information about the value returned: ```"This rectangle is 40 units squared."``` The area of a rectangle is calculated according to the equation ```area = width * height```.

# %%
def rectangle_area(width, height):
    area = width * height
    return area

print("This rectangle is " + str(rectangle_area(4,10)) + " units squared")
# Out:
# This rectangle is 40 units squared

# %% [markdown]
# 5) Write a main function that calls all the three functions in Questions 2 to 4. In your main function you should ask the user for the size of each shape, calculate the area of each shape, and print out the area. Remember that for your functions that use __returns__, you must save the value in a variable and print out the areas in your main function. Finally, use the `max` function to find which area was the largest.

# %%
def square_area(size):
    area = size * size
    return area

def triangle_area(size):
    base = size
    height = size
    area = 0.5 * base * height
    return area

def rectangle_area(width, height):
    area = width * height
    return area

def main():
    square_size = input("what is the size of the square?")
    square_A = square_area(square_size)
    print("This square is " + str(square_A) + " units squared")

    triangle_size = input("what is the size of the triangle?")
    triangle_A = triangle_area(triangle_size)
    print("This triangle is " + str(triangle_A) + " units squared")

    rectangle_width = input("what is the width of the rectangle?")
    rectangle_height = input("what is the width of the rectangle?")
    rectangle_A = rectangle_area(rectangle_width, rectangle_height)
    print("This rectangle is " + str(rectangle_A) + " units squared")

    areas = {square_A:"square", triangle_A:"triangle", rect_A:"rectangle"}
    print("The shape with the largest area is the " + str(areas.get(max(areas)) + "with a value of " + max(areas)))

# %% [markdown]
# 6) (challenge problem) Write a function, `countdown` that __returns__ how many days are between now and an event you are counting down to. This function should have four arguments/parameters: (1) the current year, (2) the absolute day in the current year (as in the question from problem 1 in the pseudocode section, e.g., April 1 is absolute day 91), (3) the year of the event you are counting to, and (4) the absolute day of the event. You may assume that leap years don’t exist.

# %%
def abs_day(month, day):
        month_name = month.upper()
        months = {"JANUARY":1, "FEBRUARY":2, "MARCH":3, "APRIL":4, "MAY":5, "JUNE":6,
                "JULY":7, "AUGUST":8, "SEPTEMBER":9, "OCTOBER":10, "NOVEMBER":11, "DECEMBER":12}
        month_number = months.get(month_name)
        days_in_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
        # NOTE: months has values 1 higher than the respective index in days_in_month, so must subtract 1
        days_until_month = 0
        for i in range(month_number-1):
                days_until_month += days_in_month[i]
        absolute_day = days_until_month + day
        return absolute_day


def countdown(current_year,current_abs_day,event_year,event_abs_day):
        current_day_val = 365 * current_year + current_abs_day
        event_day_val = 365 * event_year + event_abs_day
        return event_day_val - current_day_val
